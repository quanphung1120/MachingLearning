# %% [markdown]
# <a href="https://colab.research.google.com/github/quanphung1120/MachingLearning-LinearRegression/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([2, 3, 4])

print("Dot Product of a and b:", np.dot(a, b))
# Out:
# Dot Product of a and b: 20
